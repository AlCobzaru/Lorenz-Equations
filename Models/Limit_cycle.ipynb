# %% [markdown]
# The first imput, r, is the parameter that defines the behavior of the solution. It should be bigger than 1, yet smaller than 14 to see a limit cycle with close to none transient chaotic behavior.
# \
# The three other imputs, x, y, z, are the initial values for the three equations. Any value could be chosen for these, but I recommend to keep them between [-20, 20] in order to observe the trajectory behavior.\
# \
# I recommend to try any initial values for an r value 5 and 10.

# %%
#@title
r = int(float(input('r?')))
x = int(float(input('x?')))
y = int(float(input('y?')))
z = int(float(input('z?')))
if (r < 1 or r > 14):
  print('Pick an r value between 1 and 14')
elif (x < -20 or x > 20):
  print('Pick an x value between -20 and 20')
elif (y < -20 or y > 20):
  print('Pick an y value between -20 and 20')
elif (z < -20 or z > 20):
  print('Pick an z value between -20 and 20')
# Out:
# r?13
# x?5
# y?5
# z?5

# %%
#@title
if (r < 1 or r > 14):
  # !kill -9 -1
elif (x < -20 or x > 20):
  # !kill -9 -1
elif (y < -20 or y > 20):
  # !kill -9 -1
elif (z < -20 or z > 20):
  # !kill -9 -1

# %%
#@title
! pip install diffrax
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffrax
#   Downloading diffrax-0.3.1-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 KB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: jax>=0.4.3 in /usr/local/lib/python3.9/dist-packages (from diffrax) (0.4.7)
# Collecting equinox>=0.10.0
#   Downloading equinox-0.10.2-py3-none-any.whl (113 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 113.7/113.7 KB 9.1 MB/s eta 0:00:00
# Collecting jaxtyping>=0.2.14
#   Downloading jaxtyping-0.2.14-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /usr/local/lib/python3.9/dist-packages (from equinox>=0.10.0->diffrax) (4.5.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (1.10.1)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (1.22.4)
# Requirement already satisfied: ml-dtypes>=0.0.3 in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (0.0.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (3.3.0)
# Collecting typeguard>=2.13.3
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.13.3->jaxtyping>=0.2.14->equinox>=0.10.0->diffrax) (6.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.13.3->jaxtyping>=0.2.14->equinox>=0.10.0->diffrax) (3.15.0)
# Installing collected packages: typeguard, jaxtyping, equinox, diffrax
# Successfully installed diffrax-0.3.1 equinox-0.10.2 jaxtyping-0.2.14 typeguard-3.0.2

# %%
import time
from diffrax import diffeqsolve, ODETerm, Kvaerno5, SaveAt, PIDController
import equinox as eqx
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt

# %%
jax.config.update("jax_enable_x64", True)

# %%
class Lorenz(eqx.Module):
    s: float
    b: float
    r: float

    def __call__(self, t, y, args):
        f0 = self.s * (y[1] - y[0])
        f1 = self.r * y[0] - y[1] - y[0] * y[2]
        f2 = y[0] * y[1] - self.b * y[2]
        return jnp.stack([f0, f1, f2])

# %%
t0 = 0.0
t1 = 50.0
y0 = jnp.array([x, y, z])

# %%
@jax.jit
def main(s, b, r):
    lorenz = Lorenz(s, b, r)
    terms = ODETerm(lorenz)
    dt0 = 0.000001
    solver = Kvaerno5()
    saveat = SaveAt(ts=jnp.linspace(t0, t1, 100000))
    stepsize_controller = PIDController(rtol=1e-8, atol=1e-8)
    sol = diffeqsolve(
        terms,
        solver,
        t0,
        t1,
        dt0,
        y0,
        max_steps=100000,
        saveat=saveat,
        stepsize_controller=stepsize_controller,
    )
    return sol

# %% [markdown]
# Do and time one iteration to JIT compile everything. Then time the second iteration.

# %%
comp_start = time.time()
main(10.0, 8.0/3.0, r)
comp_end = time.time()

start = time.time()
sol = main(10.0, 8.0/3.0, r)
end = time.time()

print(f"Compiling and solving took {comp_end - comp_start} seconds.")
print(f"Solving while compiled took {sol.stats['num_steps']} steps in {end - start} seconds.")
# Out:
# Compiling and solving took 17.710522174835205 seconds.
# Solving while compiled took 600 steps in 4.501235246658325 seconds.

# %%
figx = plt.figure()
axi = figx.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 0]), jnp.max(sol.ys[:,0])))
plt.plot(sol.ts, sol.ys[:, 0], 'b')
plt.title('x - component')
plt.show()

# %%
figy = plt.figure()
axi = figy.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 1]), jnp.max(sol.ys[:, 1])))
plt.plot(sol.ts, sol.ys[:, 1], 'b')
plt.title('y - component')
plt.show()

# %%
figz = plt.figure()
axi = figz.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 2]), jnp.max(sol.ys[:,2])))
plt.plot(sol.ts, sol.ys[:, 2], 'b')
plt.title('z - component')
plt.show()

# %%
figxz = plt.figure()
axi = figxz.add_subplot(111,
                xlim=(jnp.min(sol.ys[:, 0]), jnp.max(sol.ys[:,0])),
                ylim=(jnp.min(sol.ys[:, 2]), jnp.max(sol.ys[:,2])))
plt.plot(sol.ys[:, 0], sol.ys[:, 2], 'b')
plt.title('x - component')
plt.show()
