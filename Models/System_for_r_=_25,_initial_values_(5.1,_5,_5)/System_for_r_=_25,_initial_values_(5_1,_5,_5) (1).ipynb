# %%
! pip install diffrax
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting diffrax
#   Downloading diffrax-0.3.1-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.4/140.4 KB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: jax>=0.4.3 in /usr/local/lib/python3.9/dist-packages (from diffrax) (0.4.6)
# Collecting equinox>=0.10.0
#   Downloading equinox-0.10.1-py3-none-any.whl (108 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.7/108.7 KB 7.4 MB/s eta 0:00:00
# Collecting jaxtyping>=0.2.12
#   Downloading jaxtyping-0.2.14-py3-none-any.whl (20 kB)
# Requirement already satisfied: scipy>=1.5 in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (1.10.1)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (1.22.4)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.9/dist-packages (from jax>=0.4.3->diffrax) (3.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /usr/local/lib/python3.9/dist-packages (from jaxtyping>=0.2.12->equinox>=0.10.0->diffrax) (4.5.0)
# Collecting typeguard>=2.13.3
#   Downloading typeguard-3.0.2-py3-none-any.whl (30 kB)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.9/dist-packages (from typeguard>=2.13.3->jaxtyping>=0.2.12->equinox>=0.10.0->diffrax) (6.1.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.9/dist-packages (from importlib-metadata>=3.6->typeguard>=2.13.3->jaxtyping>=0.2.12->equinox>=0.10.0->diffrax) (3.15.0)
# Installing collected packages: typeguard, jaxtyping, equinox, diffrax
# Successfully installed diffrax-0.3.1 equinox-0.10.1 jaxtyping-0.2.14 typeguard-3.0.2

# %%
import time
from diffrax import diffeqsolve, ODETerm, Kvaerno5, SaveAt, PIDController
import equinox as eqx
import jax
import jax.numpy as jnp
import matplotlib.pyplot as plt
from matplotlib import animation
import numpy as np

# %%
jax.config.update("jax_enable_x64", True)

# %%
class Lorenz(eqx.Module):
    s: float
    b: float
    r: float

    def __call__(self, t, y, args):
        f0 = self.s * (y[1] - y[0])
        f1 = self.r * y[0] - y[1] - y[0] * y[2]
        f2 = y[0] * y[1] - self.b * y[2]
        return jnp.stack([f0, f1, f2])

# %%
t0 = 0.0
t1 = 50.0
y0 = jnp.array([5.1, 5.0, 5.0])

# %%
@jax.jit
def main(s, b, r):
    lorenz = Lorenz(s, b, r)
    terms = ODETerm(lorenz)
    dt0 = 0.000001
    solver = Kvaerno5()
    saveat = SaveAt(ts=jnp.linspace(t0, t1, 100000))
    stepsize_controller = PIDController(rtol=1e-8, atol=1e-8)
    sol = diffeqsolve(
        terms,
        solver,
        t0,
        t1,
        dt0,
        y0,
        max_steps=100000,
        saveat=saveat,
        stepsize_controller=stepsize_controller,
    )
    return sol

# %% [markdown]
# Do and time one iteration to JIT compile everything. Then time the second iteration.

# %%
comp_start = time.time()
main(10.0, 8.0/3.0, 25)
comp_end = time.time()

start = time.time()
sol = main(10.0, 8.0/3.0, 25)
end = time.time()

print(f"Compiling and solving took {comp_end - comp_start} seconds.")
print(f"Solving while compiled took {sol.stats['num_steps']} steps in {end - start} seconds.")
# Out:
# Compiling and solving took 27.653362274169922 seconds.
# Solving while compiled took 4698 steps in 11.530242681503296 seconds.

# %%
figx = plt.figure()
axi = figx.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 0]), jnp.max(sol.ys[:,0])))
plt.plot(sol.ts, sol.ys[:, 0], 'b')
plt.title('x - component')
plt.show()

# %%
figy = plt.figure()
axi = figy.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 1]), jnp.max(sol.ys[:, 1])))
plt.plot(sol.ts, sol.ys[:, 1], 'b')
plt.title('y - component')
plt.show()

# %%
figz = plt.figure()
axi = figz.add_subplot(111, xlim=(0, t1), 
                ylim=(jnp.min(sol.ys[:, 2]), jnp.max(sol.ys[:,2])))
plt.plot(sol.ts, sol.ys[:, 2], 'b')
plt.title('z - component')
plt.show()

# %%
figxz = plt.figure()
axi = figxz.add_subplot(111,
                xlim=(jnp.min(sol.ys[:, 0]), jnp.max(sol.ys[:,0])),
                ylim=(jnp.min(sol.ys[:, 2]), jnp.max(sol.ys[:,2])))
plt.plot(sol.ys[:, 0], sol.ys[:, 2], 'b')
plt.title('x - component')
plt.show()

# %% [markdown]
# The value of r was kept at 25, but one of the initial values was only slightly changed, and it can be observed that the behavior of the system has entirely changed. (A notebook comparing the graphs of x(t) shows this more clearly)

# %%
# Importing Packages
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import animation

# %%
dataSet = np.array([sol.ys[:, 0], sol.ys[:, 1], sol.ys[:, 2]])  # Combining our position coordinates

# %%
def animate_func(num):
    ax.clear()  
    
    ax.plot3D(dataSet[0, :num+1], dataSet[1, :num+1], 
              dataSet[2, :num+1], c='blue')
    
    ax.scatter(dataSet[0, num], dataSet[1, num], dataSet[2, num], 
               c='blue', marker='o')
    
    ax.plot3D(dataSet[0, 0], dataSet[1, 0], dataSet[2, 0],     
               c='black', marker='o')
    
    ax.set_xlim3d([jnp.min(sol.ys[:, 0]), jnp.max(sol.ys[:, 0])])
    ax.set_ylim3d([jnp.min(sol.ys[:, 1]), jnp.max(sol.ys[:, 1])])
    ax.set_zlim3d([jnp.min(sol.ys[:, 2]), jnp.max(sol.ys[:, 2])])

    ax.set_xlabel('x')
    ax.set_ylabel('y')
    ax.set_zlabel('z')

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
anima = animation.FuncAnimation(fig, animate_func, interval=2, 
                                   frames=25000)
plt.show()

# %%
from IPython.display import HTML
HTML(anima.to_html5_video())
